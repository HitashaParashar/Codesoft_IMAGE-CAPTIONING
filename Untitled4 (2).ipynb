# %%
from google.colab import files
files.upload()  # kaggle.json upload karo

# %%
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json

# Drive mein download karo
# !kaggle datasets download adityajn105/flickr8k -p /content/drive/MyDrive/flickr8k/
# !unzip -q /content/drive/MyDrive/flickr8k/flickr8k.zip -d /content/drive/MyDrive/flickr8k/
print("Dataset saved to Drive!")

# %%
# ── Drive mount ──
from google.colab import drive
drive.mount('/content/drive')

import os
import re
import torch
import torch.nn as nn
from collections import Counter
from torch.utils.data import Dataset, DataLoader
from torch.nn.utils.rnn import pad_sequence
from PIL import Image
from torchvision import transforms, models

# ── Tokenizer ──
def tokenize(text):
    text = text.lower()
    text = re.sub(r"[^a-z\s]", "", text)
    return text.split()

# ── Vocabulary ──
all_captions = []
with open("/content/drive/MyDrive/flickr8k/captions.txt") as f:
    next(f)
    for line in f:
        _, caption = line.strip().split(',', 1)
        all_captions.append(caption)

counter = Counter()
for cap in all_captions:
    counter.update(tokenize(cap))

vocab = ['<PAD>', '<START>', '<END>', '<UNK>']
vocab += [word for word, freq in counter.items() if freq >= 5]
word2idx = {word: idx for idx, word in enumerate(vocab)}
idx2word = {idx: word for word, idx in word2idx.items()}
print("Vocabulary size:", len(vocab))

# ── Dataset ──
class FlickrDataset(Dataset):
    def __init__(self, image_dir, caption_file, word2idx, transform=None):
        self.image_dir = image_dir
        self.word2idx = word2idx
        self.transform = transform
        self.data = []
        with open(caption_file) as f:
            next(f)
            for line in f:
                img_name, caption = line.strip().split(',', 1)
                self.data.append((img_name, caption))

    def caption_to_tensor(self, caption):
        tokens = tokenize(caption)
        ids = [self.word2idx['<START>']]
        ids += [self.word2idx.get(w, self.word2idx['<UNK>']) for w in tokens]
        ids += [self.word2idx['<END>']]
        return torch.tensor(ids, dtype=torch.long)

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        img_name, caption = self.data[idx]
        img_path = os.path.join(self.image_dir, img_name)
        image = Image.open(img_path).convert('RGB')
        if self.transform:
            image = self.transform(image)
        return image, self.caption_to_tensor(caption)

# ── Transform & Dataset ──
transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406],
                         [0.229, 0.224, 0.225])
])

dataset = FlickrDataset(
    "/content/drive/MyDrive/flickr8k/Images",
    "/content/drive/MyDrive/flickr8k/captions.txt",
    word2idx, transform
)
print("Dataset size:", len(dataset))

# ── CNN Encoder ──
class CNNEncoder(nn.Module):
    def __init__(self, embed_size):
        super(CNNEncoder, self).__init__()
        resnet = models.resnet50(weights=models.ResNet50_Weights.IMAGENET1K_V1)
        modules = list(resnet.children())[:-1]
        self.resnet = nn.Sequential(*modules)
        self.linear = nn.Linear(resnet.fc.in_features, embed_size)
        for param in self.resnet.parameters():
            param.requires_grad = False

    def forward(self, images):
        features = self.resnet(images)
        features = features.reshape(features.size(0), -1)
        features = self.linear(features)
        return features

# ── LSTM Decoder ──
class LSTMDecoder(nn.Module):
    def __init__(self, embed_size, hidden_size, vocab_size, num_layers=1):
        super(LSTMDecoder, self).__init__()
        self.embedding = nn.Embedding(vocab_size, embed_size)
        self.lstm = nn.LSTM(embed_size, hidden_size, num_layers, batch_first=True)
        self.linear = nn.Linear(hidden_size, vocab_size)

    def forward(self, features, captions):
        captions = captions[:, :-1]
        embeddings = self.embedding(captions)
        features = features.unsqueeze(1)
        inputs = torch.cat((features, embeddings), dim=1)
        outputs, _ = self.lstm(inputs)
        outputs = self.linear(outputs)
        return outputs

# ── Collate function ──
def collate_fn(batch):
    images, captions = zip(*batch)
    images = torch.stack(images, 0)
    captions = pad_sequence(captions, batch_first=True, padding_value=word2idx['<PAD>'])
    return images, captions

# ── DataLoader ──
dataloader = DataLoader(
    dataset,
    batch_size=32,
    shuffle=True,
    collate_fn=collate_fn
)

# ── Device ──
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Device:", device)

# ── Models ──
embed_size = 256
hidden_size = 512
vocab_size = len(vocab)

encoder = CNNEncoder(embed_size).to(device)
decoder = LSTMDecoder(embed_size, hidden_size, vocab_size).to(device)

# ── Loss & Optimizer ──
criterion = nn.CrossEntropyLoss(ignore_index=word2idx['<PAD>'])
optimizer = torch.optim.Adam(
    list(encoder.linear.parameters()) + list(decoder.parameters()),
    lr=3e-4
)

print("Total batches per epoch:", len(dataloader))
print("\nSab kuch ready hai!")

# %%
# !pip install transformers
print("Done!")

# %%
from transformers import VisionEncoderDecoderModel, ViTImageProcessor, AutoTokenizer

model = VisionEncoderDecoderModel.from_pretrained("nlpconnect/vit-gpt2-image-captioning")
processor = ViTImageProcessor.from_pretrained("nlpconnect/vit-gpt2-image-captioning")
tokenizer = AutoTokenizer.from_pretrained("nlpconnect/vit-gpt2-image-captioning")

print("Model ready!")

# %%
import os
from PIL import Image
import matplotlib.pyplot as plt

# flickr8k se koi bhi image lo
image_folder = "/content/drive/MyDrive/flickr8k/Images"
sample_image = os.listdir(image_folder)[0]
img = Image.open(os.path.join(image_folder, sample_image)).convert("RGB")

# caption generate karo
inputs = processor(images=img, return_tensors="pt")
output = model.generate(**inputs, max_length=30)
caption = tokenizer.decode(output[0], skip_special_tokens=True)

# image + caption dikhao
plt.figure(figsize=(8, 6))
plt.imshow(img)
plt.axis('off')
plt.title(caption, fontsize=14, wrap=True)
plt.show()

print("Caption:", caption)

# %%
import random

images_list = random.sample(os.listdir(image_folder), 5)

fig, axes = plt.subplots(1, 5, figsize=(20, 4))

for i, img_name in enumerate(images_list):
    img = Image.open(os.path.join(image_folder, img_name)).convert("RGB")

    inputs = processor(images=img, return_tensors="pt")
    output = model.generate(**inputs, max_length=30)
    caption = tokenizer.decode(output[0], skip_special_tokens=True)

    axes[i].imshow(img)
    axes[i].axis('off')
    axes[i].set_title(caption, fontsize=9, wrap=True)

plt.tight_layout()
plt.show()

# %%
# !git config --global user.email "hitashaparashar@gmail.com"
# !git config --global user.name "HitashaParashar"

# !git clone https://github.com/HitashaParashar/Codesoft_IMAGE-CAPTIONING.git
# %cd Codesoft_IMAGE-CAPTIONING

# %%
readme = """# Image Captioning AI

## Project Overview
An image captioning system using pretrained ViT + GPT-2 model
that automatically generates captions for images.

## Tech Stack
- Python
- PyTorch
- HuggingFace Transformers (ViT + GPT-2)
- Flickr8k Dataset
- Google Colab

## How it works
1. ViT (Vision Transformer) extracts image features
2. GPT-2 generates captions word by word
3. Model tested on Flickr8k dataset images

## Results
Model successfully generates accurate captions for images.
Example outputs:
- "a man on a skateboard jumping over a rail"
- "a basketball player is jumping up to hit a ball"
- "a white bird with a long beak is standing on a body of water"

## Dataset
Flickr8k - 8091 images with 5 captions each
"""

with open("/content/Codesoft_IMAGE-CAPTIONING/README.md", "w") as f:
    f.write(readme)

print("README ready!")

# %%
from google.colab import files
files.upload()  # Downloads folder se .ipynb file upload karo

# %%
import shutil
import os

# uploaded notebook copy karo repository mein
for f in os.listdir("/content"):
    if f.endswith(".ipynb"):
        shutil.copy(f"/content/{f}",
                    "/content/Codesoft_IMAGE-CAPTIONING/image_captioning.ipynb")
        print(f"Copied: {f}")

# push karo
# %cd /content/Codesoft_IMAGE-CAPTIONING

# !git add .
# !git commit -m "Add image captioning project with ViT + GPT2"
# !git push origin main

# %%
import os

# dekho kaunsi ipynb files hain
for f in os.listdir("/content"):
    if f.endswith(".ipynb"):
        print(f)
# %cd /content/Codesoft_IMAGE-CAPTIONING

# nested folder issue fix
# !git rm -r --cached Codesoft_IMAGE-CAPTIONING 2>/dev/null || true

# files add karo
# !git add README.md
# !git add image_captioning.ipynb

# !git commit -m "Add image captioning project with ViT + GPT2"
# !git push origin main

# %%
github_username = "HitashaParashar"
github_token = "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"  # ghp_ se shuru hoga

print("Token starts with:", github_token[:4])
print("Token length:", len(github_token))

# %%
github_username = "HitashaParashar"
github_token = "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"
github_email = "hitashaparashar@gmail.com"

import subprocess
import os

os.system(f'git config --global user.email "{github_email}"')
os.system(f'git config --global user.name "{github_username}"')
os.system('rm -rf /content/repo')
os.system(f'git clone https://{github_username}:{github_token}@github.com/{github_username}/Codesoft_IMAGE-CAPTIONING.git /content/repo')
print("Cloned!")

# %%
with open("/content/repo/README.md", "w") as f:
    f.write("# Image Captioning AI\n\n")
    f.write("## Project Overview\n")
    f.write("An image captioning system using pretrained ViT + GPT-2 model.\n\n")
    f.write("## Tech Stack\n")
    f.write("- Python\n- PyTorch\n- HuggingFace Transformers\n- Flickr8k Dataset\n- Google Colab\n\n")
    f.write("## How it works\n")
    f.write("1. ViT extracts image features\n")
    f.write("2. GPT-2 generates captions word by word\n\n")
    f.write("## Results\n")
    f.write("- a man on a skateboard jumping over a rail\n")
    f.write("- a basketball player is jumping up to hit a ball\n")
    f.write("- a white bird with a long beak is standing on a body of water\n")

print("README ready!")

# %%
os.chdir("/content/repo")
os.system("git add README.md")
os.system('git commit -m "Add image captioning project"')
os.system(f'git push https://{github_username}:{github_token}@github.com/{github_username}/Codesoft_IMAGE-CAPTIONING.git main')
print("Pushed!")

# %%
from google.colab import files
files.upload()  # apni .ipynb file upload karo

# %%
import os
import shutil

# uploaded notebook dhundho
for f in os.listdir("/content"):
    if f.endswith(".ipynb"):
        print("Found:", f)
        shutil.copy(f"/content/{f}", "/content/repo/image_captioning.ipynb")
        print("Copied!")

os.chdir("/content/repo")
os.system("git add image_captioning.ipynb")
os.system('git commit -m "Add image captioning notebook"')
os.system(f'git push https://{github_username}:{github_token}@github.com/{github_username}/Codesoft_IMAGE-CAPTIONING.git main')
print("Notebook pushed!")

# %%
os.chdir("/content/repo")
result = os.popen("git log --oneline").read()
print(result)

# %%
os.chdir("/content/repo")
print(os.popen("git status").read())
print(os.popen("ls").read())

# %%
os.chdir("/content/repo")
os.system("git add Untitled4.ipynb")
os.system('git commit -m "Add image captioning notebook"')
os.system(f'git push https://{github_username}:{github_token}@github.com/{github_username}/Codesoft_IMAGE-CAPTIONING.git main')
print("Done!")

# %%
import os
import shutil

# drive mount karo
from google.colab import drive
drive.mount('/content/drive')

# drive mein notebook dhundho
for f in os.listdir("/content/drive/MyDrive"):
    if f.endswith(".ipynb"):
        print("Found:", f)

# %%
from google.colab import drive
drive.mount('/content/drive')

import shutil
import os

# saari ipynb files dhundho
print("Colab mein:")
for f in os.listdir("/content"):
    if f.endswith(".ipynb"):
        print(f)

print("\nDrive mein:")
for f in os.listdir("/content/drive/MyDrive"):
    if f.endswith(".ipynb"):
        print(f)

# %%
from google.colab import files
files.upload()

# %%
import os
import shutil

for f in os.listdir("/content"):
    if f.endswith(".ipynb"):
        print("Found:", f)
        os.system("pip install nbconvert -q")
        os.system(f"jupyter nbconvert --clear-output --inplace /content/{f}")
        shutil.copy(f"/content/{f}", "/content/repo/image_captioning.ipynb")

os.chdir("/content/repo")
os.system("git add image_captioning.ipynb")
os.system('git commit -m "Add notebook"')
os.system(f'git push https://{github_username}:{github_token}@github.com/{github_username}/Codesoft_IMAGE-CAPTIONING.git main')
print("Done!")
